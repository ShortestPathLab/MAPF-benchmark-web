# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')
import os
import pandas as pd
import numpy as np
# import seaborn as sns
from utilities import* 
from pandas import read_excel
from matplotlib import pyplot as plt
plt.rc('pdf',fonttype = 42)
plt.rc('ps',fonttype = 42)
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage,AnchoredOffsetbox
from matplotlib import rc, rcParams
rc('font', weight='bold')
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pymongo
from pymongo import MongoClient
from pymongo import InsertOne, DeleteMany, ReplaceOne, UpdateOne
from os import listdir
from os.path import isfile, join
import utilities as ut
ut.styles['WDG'] = '-.'
ut.styles['WDG+BP'] =(0, (1, 1))
ut.styles['WDG+CH'] = (0, (5, 1))
ut.styles['WDG+CHBP'] = '-'

ut.colors['WDG'] = 'C0'
ut.colors['WDG+BP'] = 'C1'
ut.colors['WDG+CH'] = 'C2'
ut.colors['WDG+CHBP'] = 'C3'
import datetime
from pprint import pprint

# %%
def create_algo_detail(db):
    LazyCBS = {
        "algo_name": "Lazy-CBS",
        "authors": "Gange et al.",
        "papers": "Graeme Gange, Daniel Harabor and Peter J. Stuckey. Lazy CBS: Implicit Conflict-Based Search Using Lazy Clause Generation. In Proceedings of the Twenty-Ninth International Conference on Automated Planning and Scheduling 2018.",
        "github": "https://bitbucket.org/gkgange/lazycbs/src/master/",
        "comments": "",
        'user_id':""
    }
    db['algorithms'].insert_one(LazyCBS)
    
def get_path(filename,number_of_agents):
    with open(filename) as file:
        planString = ""
        number_of_line = 0
        for line in file:
            number_of_line = number_of_line + 1
            planString  = planString + line
        planString = planString.rstrip("\n")
        if(number_of_agents != number_of_line):
            print("Agents number not matched")
    return planString

def insert_submission(db,submission,instance_id,algo_name,path):
    current_instance = db['instances'].find_one({'_id':instance_id})
    path_id = None
    if(submission['solution_cost']!= None):
        if(current_instance['lower_cost'] != None):
            if(current_instance['lower_cost'] > submission['solution_cost']):
                print("Inserting error: existing lower cost larger than submission solution cost")
#         //insert solution
        if(current_instance['solution_cost'] == None):
            submission["best_solution"]= True
            db['instances'].update_one({"_id" : instance_id},{"$set": 
                                                              {"solution_cost": submission['solution_cost'],
                                                                "solution_date":submission['date'],
                                                                "solution_path": path,
                                                                "empty": False
                                                              },
                                                              "$push":
                                                              {
                                                                 "solution_algos":{
                                                                     "algo_name": algo_name,
                                                                     "algo_id": submission['algo_id'],
                                                                     "date":submission['date'],
                                                                 }
                                                              }
                                                             })
        else:
            if(current_instance['solution_cost'] > submission['solution_cost']):
                db['submissions'].update_many({"instance_id" :  instance_id},{"$set": 
                                                      { 
                                                          "best_solution" : False
                                                      }
                                                     })
                submission["best_solution"]= True
                db['instances'].update_one({"_id" : instance_id},{"$set": 
                                                                    {
                                                                "solution_cost": submission['solution_cost'],
                                                                "solution_algos":[{
                                                                     "algo_name": algo_name,
                                                                     "algo_id": submission['algo_id'],
                                                                     "date":submission['date'],
                                                                    }],
                                                                "solution_date": submission['date'],
                                                                "solution_path": path,
                                                                "empty": False
                                                                    }
                                                             })
                
            elif (current_instance['solution_cost'] == submission['solution_cost']):
                submission["best_solution"]= True
                solution_inserted = False
                for algo in current_instance["solution_algos"]:
                    if(algo['algo_name'] == algo_name):
                        solution_inserted = True
                        
                if(solution_inserted == False):
                    db['instances'].update_one({"_id" : instance_id},{
                                                      "$push":
                                                      {
                                                         "solution_algos":{
                                                             "algo_name": algo_name,
                                                             "algo_id": submission['algo_id'],
                                                             "date":submission['date'],
                                                         }
                                                      }
                                                     })   
          
    if(submission['lower_cost'] != None):
        if(current_instance['solution_cost'] != None):
            if(submission['lower_cost'] > current_instance['solution_cost']):
                print("Inserting error: submission lower cost larger than existing solution cost")
        if(current_instance['lower_cost'] == None):
            submission["best_lower"]= True
            db['instances'].update_one({"_id" : instance_id},{"$set": 
                                                              {"lower_cost": submission['lower_cost'],
                                                                "lower_date":submission['date'],
                                                                "empty": False
                                                              },
                                                              "$push":
                                                              {
                                                                 "lower_algos":{
                                                                     "algo_name": algo_name,
                                                                     "algo_id": submission['algo_id'],
                                                                     "date":submission['date'],
                                                                 }
                                                              }
                                                             })
        
        else:
            if(current_instance['lower_cost'] < submission['lower_cost']):
                db['submissions'].update_many({"instance_id" :  instance_id},{"$set": 
                                                      { 
                                                          "best_lower" : False
                                                      }
                                                     })
                submission["best_lower"]= True
                db['instances'].update_one({"_id" : instance_id},{"$set": 
                                                                    {
                                                                "lower_cost": submission['lower_cost'],
                                                                "lower_algos":[{
                                                                     "algo_name": algo_name,
                                                                     "algo_id": submission['algo_id'],
                                                                     "date":submission['date'],
                                                                    }],
                                                                "lower_date": submission['date'],
                                                                "empty": False
                                                                    }
                                                             })
            elif (current_instance['lower_cost'] == submission['lower_cost']):
                submission["best_lower"]= True
                lower_inserted = False
                for algo in current_instance["lower_algos"]:
                    if(algo['algo_name'] == algo_name):
                        lower_inserted = True
                if(lower_inserted == False):
                    db['instances'].update_one({"_id" : instance_id},{
                                                      "$push":
                                                      {
                                                         "lower_algos":{
                                                             "algo_name": algo_name,
                                                             "algo_id": submission['algo_id'],
                                                             "date":submission['date'],
                                                         }
                                                      }
                                                     })  
        
    current_instance = db['instances'].find_one({'_id':instance_id})
    if current_instance['lower_cost'] == current_instance['solution_cost']:
        db['instances'].update_one({"_id" : instance_id},{"$set": 
                          {"closed": True}
                         })  
#     db['submissions'].insert_one(submission)
    db['submissions'].update_one({"instance_id":submission["instance_id"], "map_id":submission["map_id"],"algo_id":submission["algo_id"]}, 
                                 {"$set":
                                     {"lower_cost":submission['lower_cost'], 
                                      "solution_cost" : submission[ "solution_cost"],
                                      "date" : submission["date"],
                                      "best_lower" : submission["best_lower"],
                                      "best_solution" : submission["best_solution"]
                                     
                                     
                                     }
                                 }, upsert=True)


def verify_submission(db,submission,instance_id,algo_name,path):
    current_instance = db['instances'].find_one({'_id':instance_id})
    if(submission['solution_cost']!= None):
        if(current_instance['lower_cost'] != None):
            if(current_instance['lower_cost'] > submission['solution_cost']):
                print("submission:"+ str(submission['solution_cost']))
                print("current:"+ str(current_instance['lower_cost']))
                print("Inserting error: existing lower cost larger than submission solution cost")
    if(submission['lower_cost'] != None):
        if(current_instance['solution_cost'] != None):
            if(submission['lower_cost'] > current_instance['solution_cost']):
#                 print("")  
                print("submission:"+ str(submission['lower_cost']))
                print("current:"+ str(current_instance['solution_cost']))
                print("Inserting error: submission lower cost larger than existing solution cost")  
       
       
def insert_map_results(db,map_name):
    algo_id = db['algorithms'].find_one({"algo_name":"Lazy-CBS"})['_id']      
    algo_name = "Lazy-CBS"
    scen_type = ["even","random"]
    map_id = db["maps"].find_one({"map_name": map_name})['_id']
    for i in range(1, 26):
        for scen_t in scen_type:
            result_file = "../results/"+map_name+"/statistic/"+map_name+"-"+scen_t+"-"+str(i)+"-60"
            print(result_file)
            df1 = load_data(result_file)
            scen_data =  db['scenarios'].find_one({"map_id": map_id ,"type_id": i, "scen_type" :  scen_t})
            scen_id = scen_data['_id']
            number_agent = scen_data['instances']
            for index, row in df1.iterrows():
                if(row['num_agents'] > number_agent):
                    break;
                instance_id = db['instances'].find_one({"scen_id": scen_id ,"agents": row['num_agents']})['_id']
                submission= {
                        "map_id": map_id,
                        "instance_id" :  instance_id,
                        "algo_id": algo_id,
                        "lower_cost" : None,
                        "solution_cost": None,
                        "date": str(datetime.datetime.now().date()),
                        "best_lower": False,
                        "best_solution": False
                    }
                path = None
                if row['solution cost'] != -1:
                    path_results =  "../results/"+map_name+"/path/"+map_name+"-"+scen_t+"-"+str(i)+"-60/"+str(row['num_agents']) +"-path.txt"
                    path = get_path(path_results,row['num_agents'])
                    submission["solution_cost"] = row['solution cost']
                if row['lower_bound'] != -1:
                    submission["lower_cost"] = row['lower_bound']
                verify_submission(db,submission,instance_id,algo_name,path)
#                 insert_submission(db,submission,instance_id,algo_name,path)

def update_map_progress(db, map_name):
    map_id = db["maps"].find_one({"map_name": map_name})['_id']
    scen_type = ["even","random"]
    total_s = 0
    total_l = 0
    for i in range(1, 26):
        for scen_t in scen_type: 
            scen_id = db['scenarios'].find_one({"map_id": map_id ,"type_id": i, "scen_type" :  scen_t})['_id']
        
            num_s = db["instances"].count_documents({"scen_id" : scen_id, "closed" : True})
            num_l = db["instances"].count_documents({"scen_id" : scen_id, "solution_cost" : {"$ne":None}})
            total_s = total_s + num_s
            total_l = total_l + num_l
            db['scenarios'].update_one({"_id" : scen_id}, {"$set":{
                "instances_closed" : num_s,
                "instances_solved" : num_l
            }})
    db['maps'].update_one({"_id" : map_id}, {"$set":{
                "instances_closed" : total_s,
                "instances_solved" : total_l
            }})
    
    
def upload_map_results(db, map_name):
    insert_map_results(db,map_name)
#     update_map_progress(db, map_name)
    
def update_algo_data(db):
    algorithms = db['algorithms'].find({})
    for algo in algorithms: 
        bb = db['submissions'].count_documents({"algo_id": algo['_id'], "best_lower": True})
        cc = db['submissions'].count_documents({"algo_id": algo['_id'], "best_solution": True})
        dd = db['submissions'].count_documents({"algo_id": algo['_id'], "$expr": {"$eq": ["$lower_cost", "$solution_cost"]}})
        db['algorithms'].update_one({"_id" : algo['_id']},{"$set":{ "best_lower":bb, "best_solution":cc, "instances_closed":dd}})

# %%
url = "mongodb://localhost:27017/"
client = pymongo.MongoClient(url)
db = client['MAPF_V2']
print("Connect successfully")
update_algo_data(db)
# Out:
# Connect successfully

# %%
url = "mongodb://localhost:27017/"
client = pymongo.MongoClient(url)
db = client['MAPF_V2']
print("Connect successfully")
finished_map=[]
# create_algo_detail(db)
folder = '../results'
sub_folders = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]
for map_name in sub_folders:
    if map_name in finished_map:
        print("Skip finished map: " + map_name)
    else:
        upload_map_results(db,map_name)
# Out:
# Connect successfully
# ../results/orz900d/statistic/orz900d-even-1-60
# ../results/orz900d/statistic/orz900d-random-1-60
# ../results/orz900d/statistic/orz900d-even-2-60
# ../results/orz900d/statistic/orz900d-random-2-60
# ../results/orz900d/statistic/orz900d-even-3-60
# ../results/orz900d/statistic/orz900d-random-3-60
# ../results/orz900d/statistic/orz900d-even-4-60
# ../results/orz900d/statistic/orz900d-random-4-60
# ../results/orz900d/statistic/orz900d-even-5-60
# ../results/orz900d/statistic/orz900d-random-5-60
# ../results/orz900d/statistic/orz900d-even-6-60
# ../results/orz900d/statistic/orz900d-random-6-60
# ../results/orz900d/statistic/orz900d-even-7-60
# ../results/orz900d/statistic/orz900d-random-7-60
# ../results/orz900d/statistic/orz900d-even-8-60
# ../results/orz900d/statistic/orz900d-random-8-60
# ../results/orz900d/statistic/orz900d-even-9-60
# ../results/orz900d/statistic/orz900d-random-9-60
# ../results/orz900d/statistic/orz900d-even-10-60
# ../results/orz900d/statistic/orz900d-random-10-60
# ../results/orz900d/statistic/orz900d-even-11-60
# ../results/orz900d/statistic/orz900d-random-11-60
# ../results/orz900d/statistic/orz900d-even-12-60
# ../results/orz900d/statistic/orz900d-random-12-60
# ../results/orz900d/statistic/orz900d-even-13-60
# ../results/orz900d/statistic/orz900d-random-13-60
# ../results/orz900d/statistic/orz900d-even-14-60
# ../results/orz900d/statistic/orz900d-random-14-60
# ../results/orz900d/statistic/orz900d-even-15-60
# ../results/orz900d/statistic/orz900d-random-15-60
# ../results/orz900d/statistic/orz900d-even-16-60
# ../results/orz900d/statistic/orz900d-random-16-60
# ../results/orz900d/statistic/orz900d-even-17-60
# ../results/orz900d/statistic/orz900d-random-17-60
# ../results/orz900d/statistic/orz900d-even-18-60
# ../results/orz900d/statistic/orz900d-random-18-60
# ../results/orz900d/statistic/orz900d-even-19-60
# ../results/orz900d/statistic/orz900d-random-19-60
# ../results/orz900d/statistic/orz900d-even-20-60
# ../results/orz900d/statistic/orz900d-random-20-60
# ../results/orz900d/statistic/orz900d-even-21-60
# ../results/orz900d/statistic/orz900d-random-21-60
# ../results/orz900d/statistic/orz900d-even-22-60
# ../results/orz900d/statistic/orz900d-random-22-60
# ../results/orz900d/statistic/orz900d-even-23-60
# ../results/orz900d/statistic/orz900d-random-23-60
# ../results/orz900d/statistic/orz900d-even-24-60
# ../results/orz900d/statistic/orz900d-random-24-60
# ../results/orz900d/statistic/orz900d-even-25-60
# ../results/orz900d/statistic/orz900d-random-25-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-1-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-1-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-2-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-2-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-3-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-3-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-4-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-4-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-5-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-5-60
#
#
#
#
#
#
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-6-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-6-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-7-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-7-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-8-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-8-60
#
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-9-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-9-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-10-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-10-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-11-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-11-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-12-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-12-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-13-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-13-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-14-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-14-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-15-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-15-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-16-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-16-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-17-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-17-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-18-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-18-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-19-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-19-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-20-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-20-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-21-60
#
#
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-21-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-22-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-22-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-23-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-23-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-24-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-24-60
#
#
# ../results/maze-32-32-4/statistic/maze-32-32-4-even-25-60
# ../results/maze-32-32-4/statistic/maze-32-32-4-random-25-60
#
#
#
#
#
#
#
#
#
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-1-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-1-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-2-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-2-60
#
#
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-3-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-3-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-4-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-4-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-5-60
#
#
#
#
#
#
#
#
#
#
#
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-5-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-6-60
#
#
#
#
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-6-60
#
#
# submission:1399
# current:1400
# Inserting error: existing lower cost larger than submission solution cost
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-7-60
#
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-7-60
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-8-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-8-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-9-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-9-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-10-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-10-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-11-60
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-11-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-12-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-12-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-13-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-13-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-14-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-14-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-15-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-15-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-16-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-16-60
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-17-60
#
#
#
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-17-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-18-60
# submission:1459
# current:1460
# Inserting error: existing lower cost larger than submission solution cost
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-18-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-19-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-19-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-20-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-20-60
#
#
#
#
#
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-21-60
#
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-21-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-22-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-22-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-23-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-23-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-24-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-24-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-even-25-60
# ../results/maze-32-32-2/statistic/maze-32-32-2-random-25-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-1-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-1-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-2-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-2-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-3-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-3-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-4-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-4-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-5-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-5-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-6-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-6-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-7-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-7-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-8-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-8-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-9-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-9-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-10-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-10-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-11-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-11-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-12-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-12-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-13-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-13-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-14-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-14-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-15-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-15-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-16-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-16-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-17-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-17-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-18-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-18-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-19-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-19-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-20-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-20-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-21-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-21-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-22-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-22-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-23-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-23-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-24-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-24-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-even-25-60
# ../results/w_woundedcoast/statistic/w_woundedcoast-random-25-60
# ../results/empty-48-48/statistic/empty-48-48-even-1-60
# ../results/empty-48-48/statistic/empty-48-48-random-1-60
# ../results/empty-48-48/statistic/empty-48-48-even-2-60
# ../results/empty-48-48/statistic/empty-48-48-random-2-60
# submission:4207
# current:4209
# Inserting error: existing lower cost larger than submission solution cost
# submission:4255
# current:4257
# Inserting error: existing lower cost larger than submission solution cost
# submission:4281
# current:4283
# Inserting error: existing lower cost larger than submission solution cost
# submission:4291
# current:4293
# Inserting error: existing lower cost larger than submission solution cost
# submission:4331
# current:4333
# Inserting error: existing lower cost larger than submission solution cost
# submission:4396
# current:4398
# Inserting error: existing lower cost larger than submission solution cost
# submission:4482
# current:4484
# Inserting error: existing lower cost larger than submission solution cost
# submission:4528
# current:4530
# Inserting error: existing lower cost larger than submission solution cost
# submission:4532
# current:4534
# Inserting error: existing lower cost larger than submission solution cost
# submission:4613
# current:4615
# Inserting error: existing lower cost larger than submission solution cost
# submission:4651
# current:4653
# Inserting error: existing lower cost larger than submission solution cost
# submission:4668
# current:4670
# Inserting error: existing lower cost larger than submission solution cost
# submission:4709
# current:4711
# Inserting error: existing lower cost larger than submission solution cost
# submission:4803
# current:4805
# Inserting error: existing lower cost larger than submission solution cost
# submission:4833
# current:4835
# Inserting error: existing lower cost larger than submission solution cost
# submission:4837
# current:4839
# Inserting error: existing lower cost larger than submission solution cost
# submission:4988
# current:4990
# Inserting error: existing lower cost larger than submission solution cost
# submission:5054
# current:5056
# Inserting error: existing lower cost larger than submission solution cost
# submission:5275
# current:5277
# Inserting error: existing lower cost larger than submission solution cost
# submission:6836
# current:6838
# Inserting error: existing lower cost larger than submission solution cost
# ../results/empty-48-48/statistic/empty-48-48-even-3-60
# ../results/empty-48-48/statistic/empty-48-48-random-3-60
# ../results/empty-48-48/statistic/empty-48-48-even-4-60
# ../results/empty-48-48/statistic/empty-48-48-random-4-60
# ../results/empty-48-48/statistic/empty-48-48-even-5-60
# ../results/empty-48-48/statistic/empty-48-48-random-5-60
# ../results/empty-48-48/statistic/empty-48-48-even-6-60
# ../results/empty-48-48/statistic/empty-48-48-random-6-60
# ../results/empty-48-48/statistic/empty-48-48-even-7-60
# ../results/empty-48-48/statistic/empty-48-48-random-7-60
# ../results/empty-48-48/statistic/empty-48-48-even-8-60
# ../results/empty-48-48/statistic/empty-48-48-random-8-60
# ../results/empty-48-48/statistic/empty-48-48-even-9-60
# ../results/empty-48-48/statistic/empty-48-48-random-9-60
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 9>()
#      11     print("Skip finished map: " + map_name)
#      12 else:
# ---> 13     upload_map_results(db,map_name)
#
# Input In [21], in upload_map_results(db, map_name)
#     245 def upload_map_results(db, map_name):
# --> 246     insert_map_results(db,map_name)
#
# Input In [21], in insert_map_results(db, map_name)
#     199 if(row['num_agents'] > number_agent):
#     200     break;
# --> 201 instance_id = db['instances'].find_one({"scen_id": scen_id ,"agents": row['num_agents']})['_id']
#     202 submission= {
#     203         "map_id": map_id,
#     204         "instance_id" :  instance_id,
#    (...)
#     210         "best_solution": False
#     211     }
#     212 path = None
#
# File /usr/local/lib/python3.9/site-packages/pymongo/collection.py:1452, in Collection.find_one(self, filter, *args, **kwargs)
#    1450     filter = {"_id": filter}
#    1451 cursor = self.find(filter, *args, **kwargs)
# -> 1452 for result in cursor.limit(-1):
#    1453     return result
#    1454 return None
#
# File /usr/local/lib/python3.9/site-packages/pymongo/cursor.py:1248, in Cursor.next(self)
#    1246 if self.__empty:
#    1247     raise StopIteration
# -> 1248 if len(self.__data) or self._refresh():
#    1249     return self.__data.popleft()
#    1250 else:
#
# File /usr/local/lib/python3.9/site-packages/pymongo/cursor.py:1165, in Cursor._refresh(self)
#    1143         raise InvalidOperation(
#    1144             "Passing a 'hint' is required when using the min/max query"
#    1145             " option to ensure the query utilizes the correct index"
#    1146         )
#    1147     q = self._query_class(
#    1148         self.__query_flags,
#    1149         self.__collection.database.name,
#    (...)
#    1163         self.__exhaust,
#    1164     )
# -> 1165     self.__send_message(q)
#    1166 elif self.__id:  # Get More
#    1167     if self.__limit:
#
# File /usr/local/lib/python3.9/site-packages/pymongo/cursor.py:1052, in Cursor.__send_message(self, operation)
#    1049     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1051 try:
# -> 1052     response = client._run_operation(
#    1053         operation, self._unpack_response, address=self.__address
#    1054     )
#    1055 except OperationFailure as exc:
#    1056     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1057         # Don't send killCursors because the cursor is already closed.
#
# File /usr/local/lib/python3.9/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/pymongo/mongo_client.py:1302, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1297     operation.reset()  # Reset op in case of retry.
#    1298     return server.run_operation(
#    1299         sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1300     )
# -> 1302 return self._retryable_read(
#    1303     _cmd,
#    1304     operation.read_preference,
#    1305     operation.session,
#    1306     address=address,
#    1307     retryable=isinstance(operation, message._Query),
#    1308 )
#
# File /usr/local/lib/python3.9/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/pymongo/mongo_client.py:1420, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1418             assert last_error is not None
#    1419             raise last_error
# -> 1420         return func(session, server, sock_info, read_pref)
#    1421 except ServerSelectionTimeoutError:
#    1422     if retrying:
#    1423         # The application may think the write was never attempted
#    1424         # if we raise ServerSelectionTimeoutError on the retry
#    1425         # attempt. Raise the original exception instead.
#
# File /usr/local/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File /usr/local/lib/python3.9/site-packages/pymongo/mongo_client.py:1263, in MongoClient._socket_from_server(self, read_preference, server, session)
#    1260     elif sock_info.is_standalone:
#    1261         # Don't send read preference to standalones.
#    1262         read_preference = ReadPreference.PRIMARY
# -> 1263 yield sock_info, read_preference
#
# File /usr/local/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File /usr/local/lib/python3.9/site-packages/pymongo/mongo_client.py:1205, in MongoClient._get_socket(self, server, session)
#    1197 if (
#    1198     self._encrypter
#    1199     and not self._encrypter._bypass_auto_encryption
#    1200     and sock_info.max_wire_version < 8
#    1201 ):
#    1202     raise ConfigurationError(
#    1203         "Auto-encryption requires a minimum MongoDB version of 4.2"
#    1204     )
# -> 1205 yield sock_info
#
# File /usr/local/Cellar/python@3.9/3.9.15/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File /usr/local/lib/python3.9/site-packages/pymongo/pool.py:1435, in Pool.get_socket(self, handler)
#    1433         self.ncursors += 1
#    1434 elif sock_info.active:
# -> 1435     self.return_socket(sock_info)
#
# File /usr/local/lib/python3.9/site-packages/pymongo/pool.py:1543, in Pool.return_socket(self, sock_info)
#    1540     sock_info.active = True
#    1541     return sock_info
# -> 1543 def return_socket(self, sock_info):
#    1544     """Return the socket to the pool, or if it's closed discard it.
#    1545
#    1546     :Parameters:
#    1547       - `sock_info`: The socket to check into the pool.
#    1548     """
#    1549     txn = sock_info.pinned_txn
#
# KeyboardInterrupt:

# %%
def rewrite_hearder(filename):
    open(filename+"_re", "w").write("runtime,solution cost,lower bound,upper bound,instance name,#agents\n" + "".join(open(filename).readlines()[1:]))

# %%
folder = '../results'
sub_folders = [name for name in os.listdir(folder) if os.path.isdir(os.path.join(folder, name))]
for map_name in sub_folders:
    scen_type = ["even","random"]
    for i in range(1, 26):
        for scen_t in scen_type:
            filename = "../results/"+map_name+"/statistic/"+map_name+"-"+scen_t+"-"+str(i)+"-60"
            rewrite_hearder(filename)
